# %%
# Cálculo simbólico
from sympy import *
init_printing()

# %%
sqrt(4)
# Out:
# 2

# %%
x=Symbol('x')
(x+1)**2

x,y,z,t = symbols("x y z t")

(x+z+t)**2
expand( (x+1)**2 )
# Out:
#  2
# x  + 2⋅x + 1

# %%
r = Rational(1, 2)
q = Rational(23, 3)
r+q
# Out:
# 49/6

# %%
r.evalf()
# Out:
# 0.500000000000000

# %%
((x+1)**2)
# Out:
#        2
# (x + 1)

# %%
((x+y)**2).subs(x,2)
# Out:
#        2
# (y + 2)

# %%
plot(x*sin(x**2))

# %%
def f(x):
    return x*sin(x**2)
f(pi)
# Out:
#      ⎛ 2⎞
# π⋅sin⎝π ⎠

# %%
import numpy as np
import matplotlib.pyplot as plt
x_vec = np.linspace(-10,10,200)

lista_y = [ N( (f(x).subs(x, x_i))) for x_i in x_vec]
y_vec = np.array( lista_y )
plt.plot(x_vec, y_vec)

# %%
# Comprehensive lists (listas comprensivas)
lista = np.array( [ i**2 for i in range(6) if i !=3 ] )
lista
# Out:
# array([ 0,  1,  4, 16, 25])

# %%
# Integral impropia convergente
integrate(1/x**2, (x, 1, oo))
# Out:
# 1

# %%
# Integral impropia divergente
integrate(1/x, (x, 1, oo))
# Out:
# ∞
